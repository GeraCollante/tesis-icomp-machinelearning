# %% [markdown]
# # Unificación de base de datos del departamento Calidad Fabricación - FSI

# %%
import pandas as pd
import os
pd.options.display.max_columns = 60

# %% [markdown]
# # CAPS
# Cargamos los datos crudos desde el excel, descartamos las columnas innecesarias y cambiamos el nombre a las columnas según la necesidad. Además creamos dos tablas, una para VP y otra para VU.

# %%
qcap_path = "../AUDITORIAS/CAPS/1-  PUNTO QCAP.xlsm"
caps = pd.read_excel(qcap_path, "DATOS")
caps.drop(columns=['MES', 'SEM', 'Caja de velocidades', 'Fabrica', 'Titulo defecto', 'Comentario defecto', 'Elementos', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24','Unnamed: 25','Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Taller'], inplace=True)
caps[['ELE','INC']] = caps['Codigo defecto'].str.split("-",expand=True)
caps.rename(columns={'Familia':'FLIA', 'Usina':'USINA','Tipo  vehiculo':'TIPO', 'Avance producto':'AUDI', 'Motor':'MOTOR', 'Trasmision':'TRANS', 'Version':'VERS', 'Num. de Identificacion':'PJI', 'Codigo defecto':'DEF', 'Demerito (pt)':'DEM'}, inplace=True)
filtvp = (caps['USINA'] == 'VP')
caps_vp = caps[filtvp]
filtvu = (caps['USINA'] == 'VU')
caps_vu = caps[filtvu]
caps.head()
# Out:
#        FECHA USINA FLIA TIPO AUDI MOTOR  TRANS VERS           PJI  \
# 0 2020-01-13    VP  X67  F67  TCT  H4M-  TR4X2   E1  6.552003e+11
# 1 2020-01-13    VP  X52  L52  TCP  H4M-  TR4X2   E0  6.552003e+11
# 2 2020-01-13    VP  X52  L52  TCP  H4M-  TR4X2   E0  6.552003e+11
# 3 2020-01-13    VP  X52  L52  TCP  H4M-  TR4X2   E0  6.552003e+11
# 4 2020-01-13    VP  X52  L52  TCP  H4M-  TR4X2   E0  6.552003e+11
#
#   Numero de fabricacion  Color        DEF DEM   ELE   INC
# 0                   NaN  OV369  0225-4416  P2  0225  4416
# 1                   NaN  OV369  1001-4441  P2  1001  4441
# 2                   NaN  OV369  1400-4411  P2  1400  4411
# 3                   NaN  TEKNS  0210-4210  P2  0210  4210
# 4                   NaN  TEKNS  1400-4210  P2  1400  4210

# %%
caps['Numero de fabricacion'].unique()
# Out:
# array([nan, 'L016232', 'L016444', 'L016280', 'L016472', 'L016471',
#        'L016761', 'L016771', 'L017226', 'L017234', 'L017284', 'L317513',
#        'TEKNH', 'OV369', 'TEB76', 'TEKNS', 'NV676'], dtype=object)

# %%
caps[['AUDI', 'FECHA', 'USINA', 'FLIA', 'TIPO', 'PJI', 'ELE', 'INC', 'DEM']]
# Out:
#     AUDI      FECHA USINA  FLIA  TIPO           PJI   ELE   INC DEM
# 0    TCT 2020-01-13    VP   X67   F67  6.552003e+11  0225  4416  P2
# 1    TCP 2020-01-13    VP   X52   L52  6.552003e+11  1001  4441  P2
# 2    TCP 2020-01-13    VP   X52   L52  6.552003e+11  1400  4411  P2
# 3    TCP 2020-01-13    VP   X52   L52  6.552003e+11  0210  4210  P2
# 4    TCP 2020-01-13    VP   X52   L52  6.552003e+11  1400  4210  P2
# ..   ...        ...   ...   ...   ...           ...   ...   ...  ..
# 938  TCP 2020-07-30    VP   X52   L52  6.552033e+11  1150  4373  P2
# 939  TCP 2020-07-31    VU  H60A  H60A  6.552033e+11  1190  4119  P2
# 940  TCP 2020-07-31    VU  H60A  H60A  6.552033e+11  1053  4019  P2
# 941  TCP 2020-07-31    VP   X52   L52  6.552033e+11  1001  4443  P2
# 942  TCP 2020-07-31    VP   X52   L52  6.552033e+11  1180  4413  P2
#
# [943 rows x 9 columns]

# %% [markdown]
# # PESD VP
# Cargamos los datos crudos desde el excel, descartamos las columnas innecesarias y cambiamos el nombre a las columnas.

# %%
pesd_vp_path = "../AUDITORIAS/PESD/VP/6-PESD VP - copia.xlsm"
pesd_vp = pd.read_excel(pesd_vp_path, "Datos crudos")
pesd_vp.drop(columns=['Mes', 'Code site', 'Point de déclaration', 'Semana2','A','B','C','D','E', 'F', 'DEFECTO','Incidente2', 'Elemento2', 'FAMILIA','DEFECTO MODELO', 'Defecto2', 'Semana', 'Mes2'], inplace=True)
pesd_vp.rename(columns={'Code Localisation':'LOC', 'DEPARTAMENTO':'DPTO', 'COD DEFECTO':'DEF','Incidente':'INC', 'Elemento':'ELE','Date de déclaration':'FECHA', 'Démérite':'DEM', 'Famille':'FLIA','Type':'TIPO', 'PJI avec défaut':'PJI', 'Code UET imputée':'UET', 'Code regroupement de pilotage':'TIPODEF'}, inplace=True)
pesd_vp['AUDI'] = 'PESD'
pesd_vp
# Out:
#           FECHA FLIA TIPO           PJI  LOC Teinte        DEF  DEM  \
# 0    2020-01-08  X52  B52  6.552002e+11   M6  TEKNH  4303-1270  NaN
# 1    2020-01-08  X52  B52  6.552003e+11  NaN  TEKNH  4146-0011  NaN
# 2    2020-01-08  X52  B52  6.552003e+11  NaN  TEKNH  4468-1053  NaN
# 3    2020-01-08  X52  B52  6.552003e+11  NaN  NV676  4981-0011  NaN
# 4    2020-01-08  X52  B52  6.552003e+11   B3  OV369  4306-1180  NaN
# ...         ...  ...  ...           ...  ...    ...        ...  ...
# 1806 2020-07-28  X52  L52  6.552018e+11  NaN  OV369  7542-4530  NaN
# 1807 2020-07-28  X67  F67  6.552019e+11  NaN  OV369  4506-4150  NaN
# 1808 2020-07-28  X67  F67  6.552020e+11   D2  OV369  4816-1510  NaN
# 1809 2020-07-28  X67  F67  6.552020e+11  NaN  OV369  4616-0011  NaN
# 1810 2020-07-28  X67  F67  6.552021e+11  NaN  OV369  4441-1000  NaN
#
#             DPTO    UET TIPODEF DETECCION    Q     INC     ELE  AUDI
# 0        PINTURA  484.0     ASP       NaN  1.0  1270.0  4303.0  PESD
# 1      SOLDADURA  431.0    GMTR       NaN  1.0    11.0  4146.0  PESD
# 2        PINTURA  482.0     ASP       NaN  1.0  1053.0  4468.0  PESD
# 3      SOLDADURA  432.0    GMTR       NaN  1.0    11.0  4981.0  PESD
# 4        PINTURA  484.0     ASP       NaN  1.0  1180.0  4306.0  PESD
# ...          ...    ...     ...       ...  ...     ...     ...   ...
# 1806         SQF  151.0    FCIO       NaN  NaN  4530.0  7542.0  PESD
# 1807   SOLDADURA  422.0     MOP       NaN  NaN  4150.0  4506.0  PESD
# 1808  MONTAJE VP  140.0    DGRC       NaN  NaN  1510.0  4816.0  PESD
# 1809   SOLDADURA  432.0    GMTR       NaN  NaN    11.0  4616.0  PESD
# 1810        DIVD  300.0     ASP       NaN  NaN  1000.0  4441.0  PESD
#
# [1811 rows x 16 columns]

# %%
pesd_vp_generic = pesd_vp[['AUDI', 'FECHA', 'FLIA', 'TIPO', 'PJI', 'ELE', 'INC', 'LOC', 'DEM', 'TIPODEF', 'DPTO', 'UET']]
pesd_vp_generic.head()
filt = pesd_vp_generic['DEM'] == 'V1'
pesd_vp_generic[filt]
# Out:
#       AUDI      FECHA FLIA TIPO           PJI     ELE     INC     LOC DEM  \
# 11    PESD 2020-01-08  X52  L52  6.552002e+11  4304.0  1110.0      D6  V1
# 13    PESD 2020-01-08  X52  L52  6.552002e+11  4202.0  4690.0     NaN  V1
# 14    PESD 2020-01-08  X52  L52  6.552002e+11  5211.0  4150.0     NaN  V1
# 34    PESD 2020-01-09  X67  F67  6.552002e+11  5637.0  4700.0     NaN  V1
# 61    PESD 2020-01-13  X52  L52  6.552003e+11  4306.0   440.0      B3  V1
# 172   PESD 2020-01-17  X67  F67  6.552004e+11  5568.0  4280.0     NaN  V1
# 191   PESD 2020-01-20  X52  L52  6.552004e+11  4201.0  4850.0       3  V1
# 199   PESD 2020-01-21  X52  B52  6.552005e+11  5716.0  4150.0     NaN  V1
# 207   PESD 2020-01-21  X52  B52  6.552005e+11  4313.0  1430.0     D12  V1
# 223   PESD 2020-01-21  X52  B52  6.552005e+11  5241.0  4720.0     NaN  V1
# 272   PESD 2020-01-23  X52  L52  6.552004e+11  4214.0  4250.0     NaN  V1
# 277   PESD 2020-01-23  X52  L52  6.552004e+11  6331.0  4070.0     NaN  V1
# 292   PESD 2020-01-24  X52  B52  6.552005e+11  3903.0  4450.0     NaN  V1
# 296   PESD 2020-01-24  X52  B52  6.552005e+11  6200.0  4250.0     NaN  V1
# 353   PESD 2020-01-28  X52  L52  6.552005e+11  3931.0  4703.0     NaN  V1
# 355   PESD 2020-01-28  X52  L52  6.552005e+11  1313.0  4310.0     NaN  V1
# 426   PESD 2020-01-29  X52  L52  6.552005e+11  4443.0  1040.0     NaN  V1
# 473   PESD 2020-01-30  X52  L52  6.552005e+11  5129.0  2530.0     NaN  V1
# 482   PESD 2020-01-30  X52  L52  6.552005e+11  7444.0  3150.0     NaN  V1
# 487   PESD 2020-01-30  X52  B52  6.552005e+11     NaN     NaN     NaN  V1
# 526   PESD 2020-01-31  X52  B52  6.552005e+11     NaN     NaN     NaN  V1
# 527   PESD 2020-01-31  X52  B52  6.552005e+11     NaN     NaN     NaN  V1
# 551   PESD 2020-02-03  X52  B52  6.552007e+11  6203.0  4150.0     NaN  V1
# 578   PESD 2020-02-04  X52  B52  6.552006e+11  5665.0  4450.0     NaN  V1
# 664   PESD 2020-02-06  X52  L52  6.552006e+11  4214.0  4300.0     NaN  V1
# 665   PESD 2020-02-06  X52  L52  6.552006e+11  5247.0  2120.0     NaN  V1
# 666   PESD 2020-02-06  X52  L52  6.552006e+11  5611.0  2330.0     NaN  V1
# 790   PESD 2020-02-12  X52  B52  6.552007e+11  7207.0  4300.0     NaN  V1
# 800   PESD 2020-02-12  X52  L52  6.552007e+11  6319.0  2240.0     NaN  V1
# 839   PESD 2020-02-13  X52  L52  6.552007e+11  4468.0  1110.0     NaN  V1
# 1223  PESD 2020-03-16  X52  L52  6.552012e+11  1313.0  4590.0     NaN  V1
# 1224  PESD 2020-03-16  X52  L52  6.552012e+11  1507.0  4310.0     NaN  V1
# 1237  PESD 2020-03-18  X52  B52  6.552012e+11  4506.0    70.0     NaN  V1
# 1239  PESD 2020-03-18  X52  L52  6.552012e+11  5621.0  2330.0     NaN  V1
# 1271  PESD 2020-06-01  X52  B52  6.552012e+11  6318.0  4720.0     NaN  V1
# 1278  PESD 2020-06-02  X52  B52  6.552013e+11  5807.0  4300.0     NaN  V1
# 1298  PESD 2020-06-04  X52  L52  6.552013e+11  6103.0  2240.0     NaN  V1
# 1302  PESD 2020-06-05  X52  B52  6.552013e+11  5601.0  4150.0     NaN  V1
# 1347  PESD 2020-06-09  X52  L52  6.552013e+11  4417.0  1520.0     NaN  V1
# 1358  PESD 2020-06-10  X52  L52  6.552013e+11  5215.0  4700.0     NaN  V1
# 1383  PESD 2020-06-11  X52  L52  6.552014e+11  6220.0  4260.0     NaN  V1
# 1503  PESD 2020-06-23  X52  B52  6.552019e+11  4886.0  2590.0     NaN  V1
# 1510  PESD 2020-06-23  X67  F67  6.552015e+11  7044.0  4700.0     NaN  V1
# 1549  PESD 2020-06-25  X67  F67  6.552016e+11  5575.0  6160.0     NaN  V1
# 1553  PESD 2020-06-25  X67  K67  6.552017e+11  4313.0  4690.0     NaN  V1
# 1557  PESD 2020-06-26  X52  B52  6.552014e+11  3901.0  2330.0     NaN  V1
# 1566  PESD 2020-06-26  X52  B52  6.552019e+11  6203.0  2120.0     NaN  V1
# 1569  PESD 2020-06-26  X67  F67  6.552015e+11  4374.0  1530.0    FGH8  V1
# 1613  PESD 2020-07-06  X52  L52           NaN     NaN     NaN     NaN  V1
# 1653  PESD 2020-07-08  X67  F67  6.552017e+11  4813.0  1510.0     NaN  V1
# 1765  PESD 2020-07-21  X67  F67  6.552018e+11  4775.0  1510.0  O5O6O7  V1
# 1766  PESD 2020-07-21  X67  F67  6.552018e+11  4709.0  3420.0     NaN  V1
#
#      TIPODEF        DPTO    UET
# 11      DGRC     PINTURA  483.0
# 13       MOP     PINTURA  147.0
# 14       MOP     MONTAJE  421.0
# 34      FTES     PINTURA  200.0
# 61       ASP   SOLDADURA  427.0
# 172      MOP     MONTAJE  140.0
# 191      MOP     MONTAJE  484.0
# 199      MOP         SQF  140.0
# 207      ASP     PINTURA  484.0
# 223     FTES  MONTAJE VP  145.0
# 272      MOP   SOLDADURA  151.0
# 277      MOP  MONTAJE VP  141.0
# 292     NCON  MONTAJE VP  132.0
# 296      MOP  MONTAJE VP  142.0
# 353     FTES  MONTAJE VP  132.0
# 355      NaN  MONTAJE VP  144.0
# 426      ASP     PINTURA  482.0
# 473      ASP     PINTURA  484.0
# 482      MOP         SQF  151.0
# 487      NaN     PINTURA    NaN
# 526      NaN  MONTAJE VP    NaN
# 527      NaN     PINTURA    NaN
# 551      MOP  MONTAJE VP  300.0
# 578     NCON  MONTAJE VP  140.0
# 664     NCON   SOLDADURA  421.0
# 665      MOP  MONTAJE VP  160.0
# 666      MOP  MONTAJE VP  151.0
# 790      NaN  MONTAJE VP  140.0
# 800      NaN         SQF  151.0
# 839      ASP     PINTURA  484.0
# 1223     NaN  MONTAJE VP  136.0
# 1224     MOP  MONTAJE VP  145.0
# 1237    GMTR   SOLDADURA  432.0
# 1239     MOP  MONTAJE VP  151.0
# 1271     NaN  MONTAJE VP  142.0
# 1278    NCON  MONTAJE VP  151.0
# 1298    FCIO  MONTAJE VP  300.0
# 1302     MOP  MONTAJE VP  300.0
# 1347    DGRC  MONTAJE VP  137.0
# 1358    FTES  MONTAJE VP  160.0
# 1383     MOP  MONTAJE VP  142.0
# 1503     MOP   SOLDADURA  160.0
# 1510    FTES  MONTAJE VP  142.0
# 1549    FCIO         SQF  140.0
# 1553     MOP   SOLDADURA  427.0
# 1557     MOP         SQF  132.0
# 1566     MOP         SQF  142.0
# 1569     ASP  MONTAJE VP  481.0
# 1613     ASP     PINTURA    NaN
# 1653    DGRC  MONTAJE VP  484.0
# 1765    DGRC   SOLDADURA  431.0
# 1766    GMTR   SOLDADURA  432.0

# %% [markdown]
# # SAVES VP
# Cargamos los datos crudos desde el excel, descartamos las columnas innecesarias y cambiamos el nombre a las columnas.
#
# *TO-DO*: normalizar TIPODEF.

# %%
saves_vp_path = "../AUDITORIAS/SAVES/VP/8-SAVES VP.xlsm"
saves_vp = pd.read_excel(saves_vp_path, "Datos")
saves_vp.drop(columns=['Año', 'Mes', 'GEOMETRIA', 'OPERADOR FUGA CHECKMAN', 'ZONA', 'PILOTO', 'DETECCION PINTURA', 'DETECCION MONTAJE', 'RETOCADOR PINTURA', 'RETOCADOR MONTAJE', 'Z', 'RETOCADOR MONTAJE','PESD', 'PUESTO FUGA CHECKMAN', 'PUESTO FUGA CSC /CSCD', 'ZONA CHECKMAN', 'OPERADOR FUGA CSC/CSCD', 'Semana', 'Fabrica', 'NA AR', 'PRO-PIE', 'DEFECTO', 'Defecto', 'ORIGEN', 'VALIDADOR','Retocador','UET'], inplace=True)
saves_vp[['ELE','INC']] = saves_vp['Codigo'].str.split("-",expand=True)
saves_vp.rename(columns={'Avance PIEZA':'PIEZA', 'Codigo':'DEF', 'Numero de fabricacion':'NFAB', 'Día':'FECHA', 'FAMILIA':'FLIA', 'Tipo  vehiculo':'TIPO', 'Motor':'MOTOR', 'Caja de velocidades':'CVELO', 'Trasmision':'TRANS', 'Version':'VERS', 'Num. de Identificacion':'PJI', 'DEMERITO':'DEM', 'GRUPOS':'TIPODEF'}, inplace=True)
# saves_vp['Avance PIEZA'].value_counts(dropna=False)
saves_vp['AUDI'] = 'SAVES'
# saves_vp.head(5)

# %%
saves_vp.head(3)
saves_vp_generic = saves_vp[['AUDI', 'FECHA', 'FLIA', 'TIPO', 'PJI', 'ELE', 'INC', 'DEM', 'TIPODEF', 'DPTO']]

# %%
saves_vp_generic['PJI'].value_counts()
filt = saves_vp_generic['DEM'] == 'V1'
saves_vp_generic[filt]
# Out:
#       AUDI      FECHA FLIA TIPO           PJI   ELE   INC DEM  \
# 0    SAVES 2020-01-27  X52  B52  655200530180  2330  7166  V1
# 63   SAVES 2020-01-31  X67  K67  655200540007  2120  5225  V1
# 96   SAVES 2020-02-04  X67  K67  655200530004  2120  5652  V1
# 150  SAVES 2020-02-11  X67  K67  655200550007  1000  4313  V1
# 155  SAVES 2020-02-12  X52  B52  655200810035  0240  4313  V1
# 178  SAVES 2020-02-13  X52  L52  655200710160   NaN   NaN  V1
# 204  SAVES 2020-02-17  X52  BCR  655200710219  4250  5219  V1
# 209  SAVES 2020-02-17  X52  BCR  655200810219  2170  6716  V1
# 265  SAVES 2020-02-21  X52  B52  655200710197  3110  7924  V1
# 370  SAVES 2020-03-04  X52  L52  655201010076  1510  4448  V1
# 440  SAVES 2020-03-12  X52  BCR  655201150146  1450  4504  V1
# 449  SAVES 2020-03-13  X52  B52  655201140086  1222  4508  V1
# 457  SAVES 2020-03-13  X67  F67  655201120069  4690  4776  V1
# 477  SAVES 2020-03-16  X52  BCR  655201110155  1450  4305  V1
# 478  SAVES 2020-03-16  X67  K67  655200610007  0240  4415  V1
# 480  SAVES 2020-03-16  X67  K67  655200610007  1450  4827  V1
# 481  SAVES 2020-03-16  X67  K67  655200610007  8700  4816  V1
# 483  SAVES 2020-03-16  X67  K67  655200610007  3420  4815  V1
# 492  SAVES 2020-03-16  X52  L52  655201150199  1530  4415  V1
# 499  SAVES 2020-03-17  X67  K67  655201150063  1091  4313  V1
# 556  SAVES 2020-07-08  X52  B52  655201940071  2240  5211  V1
# 579  SAVES 2020-07-14  X52  L52  655201740140  4720  6339  V1
# 592  SAVES 2020-07-15  X67  K67  655201830032  1510  4303  V1
# 636  SAVES 2020-07-17  X52  L52  655201750149  1270  4373  V1
# 714  SAVES 2020-07-28  X67  F67  655201920097  3730  7317  V1
#
#              TIPODEF       DPTO
# 0            ASPECTO    MONTAJE
# 63   MODO OPERATORIO    MONTAJE
# 96   MODO OPERATORIO    MONTAJE
# 150          ASPECTO  SOLDADURA
# 155          ASPECTO  SOLDADURA
# 178   FUNCIONAMIENTO    MONTAJE
# 204  MODO OPERATORIO    MONTAJE
# 209          ASPECTO        DLI
# 265   FUNCIONAMIENTO    MONTAJE
# 370      DEGRADACION    PINTURA
# 440  MODO OPERATORIO    MONTAJE
# 449          ASPECTO    PINTURA
# 457  MODO OPERATORIO    MONTAJE
# 477  MODO OPERATORIO  SOLDADURA
# 478  MODO OPERATORIO    PINTURA
# 480  MODO OPERATORIO  SOLDADURA
# 481           RUIDOS  SOLDADURA
# 483        GEOMETRIA  SOLDADURA
# 492      DEGRADACION    MONTAJE
# 499  MODO OPERATORIO    PINTURA
# 556        GEOMETRIA    MONTAJE
# 579  MODO OPERATORIO    MONTAJE
# 592      DEGRADACION    PINTURA
# 636          ASPECTO    PINTURA
# 714   FUNCIONAMIENTO    MONTAJE

# %%
pd.concat([pesd_vp_generic, saves_vp_generic], sort=True)
# Out:
#       AUDI  DEM       DPTO   ELE      FECHA FLIA   INC  LOC           PJI  \
# 0     PESD  NaN    PINTURA  4303 2020-01-08  X52  1270   M6  6.552002e+11
# 1     PESD  NaN  SOLDADURA  4146 2020-01-08  X52    11  NaN  6.552003e+11
# 2     PESD  NaN    PINTURA  4468 2020-01-08  X52  1053  NaN  6.552003e+11
# 3     PESD  NaN  SOLDADURA  4981 2020-01-08  X52    11  NaN  6.552003e+11
# 4     PESD  NaN    PINTURA  4306 2020-01-08  X52  1180   B3  6.552003e+11
# ..     ...  ...        ...   ...        ...  ...   ...  ...           ...
# 756  SAVES   V2  SOLDADURA  0240 2020-07-30  X52  4313  NaN  6.552033e+11
# 757  SAVES   V2        SQF  4450 2020-07-30  X52  5645  NaN  6.552033e+11
# 758  SAVES   V2  SOLDADURA  0031 2020-07-30  X52  4910  NaN  6.552033e+11
# 759  SAVES   V2    PINTURA  1180 2020-07-30  X52  4313  NaN  6.552033e+11
# 760  SAVES   V2  SOLDADURA  0021 2020-07-30  X52  4506  NaN  6.552033e+11
#
#     TIPO      TIPODEF    UET
# 0    B52          ASP  484.0
# 1    B52         GMTR  431.0
# 2    B52          ASP  482.0
# 3    B52         GMTR  432.0
# 4    B52          ASP  484.0
# ..   ...          ...    ...
# 756  L52      ASPECTO    NaN
# 757  L52  DEGRADACION    NaN
# 758  L52    GEOMETRIA    NaN
# 759  L52      ASPECTO    NaN
# 760  L52    GEOMETRIA    NaN
#
# [2572 rows x 12 columns]

# %% [markdown]
# # PESD VU

# %% [markdown]
# # SAVES VU
# Cargamos los datos crudos desde el excel, descartamos las columnas innecesarias y cambiamos el nombre a las columnas.

# %%
saves_vu_path = "../AUDITORIAS/SAVES/VU/SAVES VU + Tablero Integrado.xlsm"
saves_vu = pd.read_excel(saves_vu_path, "Datos")
saves_vu.drop(columns=['Año', 'Mes', 'Semana','Defecto', 'A', 'Fabrica', 'VALIDADOR', 'GEOMETRIA', 'COMENTARIO', 'DETECCION PINTURA', 'OPERADOR FUGA CSC/CSCD', 'PUESTO FUGA CHECKMAN', 'ZONA CHECKMAN', 'OPERADOR FUGA CHECKMAN', 'Retocador', 'UET', 'DETECCION MONTAJE', 'PUESTO FUGA CSC /CSCD', 'ZONA', 'PESD','DEFECTO', 'Titulo defecto', 'PRO-PIE', 'ORIGEN'], inplace=True)
saves_vu[['ELE','INC']] = saves_vu['Codigo'].str.split("-",expand=True)
saves_vu.rename(columns={'Día':'FECHA', 'FAMILIA':'FLIA', 'DEMERITO':'DEM','Codigo':'DEF', 'Tipo  vehiculo':'TIPO', 'Avance PIEZA':'PIEZA', 'Motor':'MOTOR', 'Caja de velocidades':'CVELO', 'Trasmision':'TRANS', 'Version':'VERS','Num. de Identificacion':'PJI', 'Numero de fabricacion':'NFAB', 'GRUPOS':'TIPODEF'}, inplace=True)
saves_vu['AUDI'] = 'SAVES'

# %%
saves_vu.head(3)
saves_vu_generic = saves_vu[['AUDI', 'FECHA', 'FLIA', 'TIPO', 'PJI', 'ELE', 'INC', 'DEM', 'TIPODEF', 'DPTO']]

# %% [markdown]
# # DPU VU
# Cargamos los datos crudos desde el excel, descartamos las columnas innecesarias y cambiamos el nombre a las columnas.

# %%
dpu_vu_path = "../AUDITORIAS/DPU/VU/DATOS VU 2020 OK - copia.xlsm"
dpu_vu = pd.read_excel(dpu_vu_path, "DATOS")
dpu_vu.drop(columns=['SEMANA','MES', 'ELEMNTO Final', 'ELEMNTO Libellé', 'Libellé localisation', 'DECLARACION UET', 'DECLARACION Equ.', 'RETOQUE UET', 'INCIDENTE Final', 'DEFECTOS', 'INCIDENTE Libellé', 'UET IMPUTACION', 'IMPUTACION Equ.', 'QRQC N1'], inplace=True)
dpu_vu.rename(columns={'DÍA':'FECHA', 'Code regroupement de pilotage':'TIPODEF', 'IMPUTACION Ate.':'TALLER', 'IMPUTACIONUET':'UET', 'Dém.':'DEM', 'IMPUTACIONDép.':'DPTO', 'Famille':'FLIA','Type':'TIPO', 'ELEMENTO Init.':'ELE', 'INCIDENTE Init.':'INC', 'Code Localisation':'LOC'}, inplace=True)
dpu_vu['AUDI'] = 'DPU'

# %%
dpu_vu_generic = dpu_vu[['AUDI','FECHA','PJI', 'FLIA', 'TIPO', 'ELE', 'INC', 'LOC', 'TIPODEF', 'DEM', 'DPTO', 'TALLER', 'UET']]
dpu_vu_generic
# Out:
#       AUDI               FECHA           PJI FLIA TIPO   ELE   INC  LOC  \
# 0      DPU 2020-01-21 08:28:23  655194510042  XND  HND  4506  1510
# 1      DPU 2020-01-21 08:28:23  655194510042  XND  HND  4514  0230  U54
# 2      DPU 2020-01-21 08:28:23  655194510042  XND  HND  4520  0210  V73
# 3      DPU 2020-01-21 08:28:23  655194510042  XND  HND  5226  4150
# 4      DPU 2020-01-21 08:28:23  655194510042  XND  HND  5710  4300
# ...    ...                 ...           ...  ...  ...   ...   ...  ...
# 73291  DPU 2020-07-24 00:00:00  655203210041  XND  HND  5601  4300  NaN
# 73292  DPU 2020-07-24 00:00:00  655203210041  XND  HND  5645  2240  NaN
# 73293  DPU 2020-07-24 00:00:00  655203210041  XND  HND  5799  4250  NaN
# 73294  DPU 2020-07-24 00:00:00  655203210041  XND  HND  6105  2120  NaN
# 73295  DPU 2020-07-24 00:00:00  655203210041  XND  HND  7773  CK01  NaN
#
#       TIPODEF  DEM    DPTO TALLER  UET
# 0        DGRC   V2   DPINT  PTAL2  484
# 1         ASP  NaN     SQF    SQF  151
# 2        DGRC   V1   DCHAP  TOLE3  657
# 3         MOP  NaN  MONTVU  CH-ME  609
# 4        NCON  NaN     SQF    SQF  151
# ...       ...  ...     ...    ...  ...
# 73291    NCON  NaN     SQF    SQF  151
# 73292    FCIO  NaN     SQF    SQF  151
# 73293     MOP  NaN  MONTVU   TRIM  600
# 73294     MOP  NaN   DCHAP  TOLE3  427
# 73295    ELEC  NaN     DAT  INGEN  300
#
# [73296 rows x 13 columns]

# %% [markdown]
# # DPU VP

# %%
dpu_vp_path = "../AUDITORIAS/DPU/VP/DATOS 2020.xlsm"
dpu_vp = pd.read_excel(dpu_vp_path, "datos")
dpu_vp['AUDI'] = 'DPU'
dpu_vp.rename(columns={'fecha':'FECHA', 'Famille':'FLIA', 'Dép.':'DPTO', 'loc':'LOC', 'Type':'TIPO', 'cod elem':'ELE', 'cod inc':'INC', 'dem':'DEM', 'Dép':'DPTO','Ate.':'TALLER', 'Code regroupement de pilotage':'TIPODEF'}, inplace=True)
# dpu_vp.drop(columns=['SEMANA','MES', 'ELEMNTO Final', 'ELEMNTO Libellé', 'Libellé localisation', 'DECLARACION UET', 'DECLARACION Equ.', 'RETOQUE UET', 'INCIDENTE Final', 'DEFECTOS', 'INCIDENTE Libellé', 'UET IMPUTACION', 'IMPUTACION Equ.', 'QRQC N1'], inplace=True)
# dpu_vp.rename(columns={'DÍA':'FECHA', 'Code regroupement de pilotage':'TIPODEF', 'IMPUTACION Ate.':'TALLER', 'IMPUTACIONUET':'UET', 'Dém.':'DEM', 'IMPUTACIONDép.':'DPTO', 'Famille':'FLIA','Type':'TIPO', 'ELEMENTO Init.':'ELE', 'INCIDENTE Init.':'INC', 'Code Localisation':'LOC'}, inplace=True)

# %%
dpu_vp_generic = dpu_vp[['AUDI','FECHA','PJI', 'FLIA', 'TIPO', 'ELE', 'INC', 'LOC', 'TIPODEF', 'DEM', 'DPTO', 'TALLER', 'UET']]

# %%
dpu_vp_generic.head()
filt = dpu_vp_generic['PJI'] == 655201920097
dpu_vp_generic[filt]
# Out:
#       AUDI      FECHA           PJI FLIA TIPO   ELE   INC   LOC TIPODEF  DEM  \
# 40282  DPU 2020-07-27  655201920097  X67  F67  4373  2150  JKL8     ASP  NaN
# 40283  DPU 2020-07-27  655201920097  X67  F67  4401  0230    M4     ASP  NaN
# 40284  DPU 2020-07-27  655201920097  X67  F67  4768  0703    B3     ASP   V2
# 40285  DPU 2020-07-27  655201920097  X67  F67  7773  4797   120    ELEC  V2F
#
#         DPTO TALLER  UET
# 40282  DMONT  MONT1  141
# 40283    SQF    SQF  151
# 40284  DCHAP  TOLE3  426
# 40285    SQF    SQF  151

# %%
dpu_vp_generic['PJI'].value_counts()
filt = dpu_vp_generic.PJI == 655203140057
dpu_vp_generic[filt]
# Out:
#       AUDI      FECHA           PJI FLIA TIPO   ELE   INC     LOC TIPODEF  \
# 41730  DPU 2020-07-30  655203140057  X52  L52  4210  1180     A11     ASP
# 41731  DPU 2020-07-30  655203140057  X52  L52  4303  1220      P6     ASP
# 41732  DPU 2020-07-30  655203140057  X52  L52  4304  1220      C6     ASP
# 41733  DPU 2020-07-30  655203140057  X52  L52  4313  1180     F12     ASP
# 41734  DPU 2020-07-30  655203140057  X52  L52  4373  1180  K10L10     ASP
# 41735  DPU 2020-07-30  655203140057  X52  L52  4402  1180      E4     ASP
# 41736  DPU 2020-07-30  655203140057  X52  L52  4403  1170      P5     ASP
# 41737  DPU 2020-07-30  655203140057  X52  L52  4403  1180      P4     ASP
# 41738  DPU 2020-07-30  655203140057  X52  L52  4415  1180     NaN     ASP
# 41739  DPU 2020-07-30  655203140057  X52  L52  4416  1180     NaN     ASP
# 41740  DPU 2020-07-30  655203140057  X52  L52  4441  1000     NaN     ASP
# 41741  DPU 2020-07-30  655203140057  X52  L52  4442  1000     NaN     ASP
# 41742  DPU 2020-07-30  655203140057  X52  L52  4443  1000     NaN     ASP
# 41743  DPU 2020-07-30  655203140057  X52  L52  4444  1000     NaN     ASP
# 41744  DPU 2020-07-30  655203140057  X52  L52  4444  1020     NaN     ASP
# 41745  DPU 2020-07-30  655203140057  X52  L52  4466  1001     NaN     ASP
# 41746  DPU 2020-07-30  655203140057  X52  L52  4466  1270     NaN     ASP
# 41747  DPU 2020-07-30  655203140057  X52  L52  4514  1180      B4     ASP
# 41748  DPU 2020-07-30  655203140057  X52  L52  4520  1180     P11     ASP
# 41749  DPU 2020-07-30  655203140057  X52  L52  4839  1270     G12     ASP
# 41750  DPU 2020-07-30  655203140057  X52  L52  4917  0020     NaN    GMTR
# 41751  DPU 2020-07-30  655203140057  X52  L52  6110  9000     DER    ESTQ
#
#        DEM   DPTO TALLER  UET
# 41730  NaN  DPINT  PTAL2  483
# 41731  NaN  DPINT  PTAL2  483
# 41732  NaN  DPINT  PTAL2  483
# 41733  NaN  DPINT  PTAL2  484
# 41734  NaN  DPINT  PTAL2  484
# 41735  NaN  DPINT  PTAL2  484
# 41736  NaN  DPINT  PTAL2  484
# 41737  NaN  DPINT  PTAL2  484
# 41738  NaN  DPINT  PTAL2  483
# 41739  NaN  DPINT  PTAL2  486
# 41740  NaN    DAT  INGEN  300
# 41741  NaN    DAT  INGEN  300
# 41742  NaN    DAT  INGEN  300
# 41743  NaN    DAT  INGEN  300
# 41744  NaN  DPINT  PTAL1  482
# 41745  NaN    DAT  INGEN  300
# 41746  NaN  DPINT  PTAL2  484
# 41747  NaN  DPINT  PTAL2  483
# 41748  NaN  DPINT  PTAL2  484
# 41749  NaN  DPINT  PTAL2  486
# 41750  NaN  DCHAP  TOLE4  432
# 41751   V1  DMONT   MONT  456

# %% [markdown]
# # GQU

# %%
gqu_path = "../ANIMACIONES/QRQC/GQU/Datos_brutos.xlsx"
gqu = pd.read_excel(gqu_path, "Export_Data")
gqu.drop(columns=['Factoría', 'Nombre de la factoría', 'Nombre departamento', 'Descripción del defecto','Descripción', 'Fecha de creación.1', 'Código incidente de la alerta', 'Nombre taller', 'Nombre UET', 'Código elemento de la alerta'], inplace=True)
gqu.rename(columns={'Dossier de calidad':'DOSSIER', 'Origen':'ORIGEN', 'Alerta':'ALERTA', 'Fecha de creación':'FECHA', 'Nombre elemento del dossier de calidad': 'ELE', 'Localización':'LOC', 'Tipo':'TIPO', 'Código departamento':'DPTO', 'Código taller':'TALLER', 'Código UET':'UET', 'Código elemento del dossier de calidad': 'INC', 'Criticidad':'DEM'}, inplace=True)

# %%
# pd.options.display.max_columns = 500
gqu_generic = gqu[['FECHA', 'DOSSIER', 'ELE', 'INC', 'LOC', 'DEM', 'ALERTA', 'ORIGEN', 'DPTO', 'TALLER', 'UET']]
gqu_generic
# gqu[['FECHA', 'ELE', 'INC']]
# df['Name']='abc'
# Out:
#                  FECHA    DOSSIER   ELE   INC  LOC  DEM    ALERTA     ORIGEN  \
# 0     23/07/2020 09:43  QF0169889  4398  0441  NaN   I2  A0295361  PLAN SURV
# 1     23/07/2020 09:36  QF0169886  20AE  0041  NaN   P1  A0295357      SECTO
# 2     22/07/2020 12:29  QF0169813  4775  8952  NaN   I2  A0295226        PEI
# 3     22/07/2020 08:20  QF0169788  4214  0706  NaN   I2  A0295180        PEI
# 4     21/07/2020 14:50  QF0169717  1700  4260  NaN   V1  A0295065      CSC-S
# ...                ...        ...   ...   ...  ...  ...       ...        ...
# 7934  16/05/2017 10:36  QF0076537  5216  0030  NaN   V1  A0123182       PESD
# 7935  29/02/2016 11:38  QF0040730  36AR  0908  NaN   K3  A0060318        GMF
# 7936  22/02/2016 12:59  QF0040195  8103  3110  NaN  DRG  A0059394        GMF
# 7937  22/02/2016 09:53  QF0040165  5611  0008  NaN  DRG  A0059353        GMF
# 7938  15/02/2016 13:44  QF0039596  3139  4150  NaN   K3  A0058413        GMF
#
#         DPTO TALLER  UET
# 0      DCHAP  TOLE3  427
# 1        DAT    NaN  NaN
# 2      DCHAP  TOLE1  422
# 3      DCHAP    NaN  NaN
# 4     MONTVU  CH-ME  609
# ...      ...    ...  ...
# 7934     DAT    NaN  NaN
# 7935   DMONT  MONT1  140
# 7936   DMONT  MONTA  131
# 7937   DMONT  MONTA  137
# 7938   DMONT  MONTA  131
#
# [7939 rows x 11 columns]

# %% [markdown]
# # DSTAR VP

# %%
import datetime
my_date = datetime.date.today() # if date is 01/01/2018
year, my_week, day_of_week = my_date.isocalendar()
# print("Week #" + str(my_week-1) + " of year " + str(year))
dstar_path = "../AUDITORIAS/DSTAR/DSTAR KO VP S" +  str(my_week-1) + ".xlsx"
dstar = pd.read_excel(dstar_path, "Defectos")
new_header = dstar.iloc[0]
dstar = dstar[1:]
dstar.columns = new_header
dstar.rename(columns={'Fórmula PJI':'PJI', 'Famille':'FLIA', 'Code incident':'INC', 'Démérite':'DEM', 'Code Localisation':'LOC', 'Horodatage de déclaration':'FECHA DEC', 'Code UET imputée':'UET', 'Code département imputé':'DPTO','Horodatage de retouche':'FECHA RET'}, inplace=True)
# dpu_vp['AUDI'] = 'DPU'
# dpu_vp.rename(columns={'fecha':'FECHA', 'Famille':'FLIA', 'Dép.':'DPTO', 'loc':'LOC', 'Type':'TIPO', 'cod elem':'ELE', 'cod inc':'INC', 'dem':'DEM', 'Dép':'DPTO','Ate.':'TALLER', 'Code regroupement de pilotage':'TIPODEF'}, inplace=True)

# %%
# dstar.head()
# FALTA ELE, TALLER
# FALTA VU
dstar_generic = dstar[['FECHA DEC', 'PJI', 'FLIA', 'INC', 'DEM', 'LOC', 'DPTO', 'UET']]
# Out:
# X52    1215
# X67     939
# Name: FLIA, dtype: int64

# %%
dstar['PJI'].value_counts()
# Out:
# 655203140057    22
# 655202120081    19
# 655203330046    15
# 655202110082    14
# 655201910098    14
#                 ..
# 655203310067     1
# 655203310130     1
# 655203610025     1
# 655203620011     1
# 655202140077     1
# Name: PJI, Length: 390, dtype: int64
