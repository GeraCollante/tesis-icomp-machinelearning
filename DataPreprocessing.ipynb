# %%
import pandas as pd
import numpy as np
import os 

# Set max columns
pd.set_option('display.max_columns', None)

DATADIR = 'data/2020'
OTHERDIR = 'data/misc/'

# Set paths
DATASET = os.path.join(DATADIR, '2020.csv')
DATAOUTPUT =  os.path.join(DATADIR, '2020pp.csv')
HIERARCHY = os.path.join(OTHERDIR, 'hierarchy.xlsx')

# %%
df = pd.read_csv(DATASET, index_col=[0])
# Out:
# /usr/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (11) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df
# Out:
#         AUDI                        DECL  DPTO   ELE GVD   INC INOFFDPTO  \
# 0       CAPS  2020-01-27 09:00:00.000000  SOLD  4120  V2   180       NaN
# 1       CAPS  2020-01-27 09:00:00.000000  PINT  4466  V2  1010       NaN
# 2       CAPS  2020-01-27 09:00:00.000000  PINT  4420  V2  1110       NaN
# 3       CAPS  2020-01-27 09:00:00.000000  PINT  4412  V2  1180       NaN
# 4       CAPS  2020-01-27 09:00:00.000000  PINT  4414  V2  1270       NaN
# ...      ...                         ...   ...   ...  ..   ...       ...
# 235533  PESD         2020-12-30 09:06:00  PINT  4502  V2  1000       NaN
# 235534  PESD         2020-12-30 10:03:00  SOLD  7887  V2  3220       NaN
# 235535  PESD         2020-12-30 10:03:00  MONT  5215  V2  4450       NaN
# 235536  PESD         2020-12-30 10:03:00  PINT  4401  V2  1190       NaN
# 235537  PESD         2020-12-30 10:03:00  SOLD  4506  V2  1510       NaN
#
#        INOFFUSI   LOC MADU           PJI RETO TALL  TIPO  UET  ZONA
# 0           NaN   NaN  NaN  655200530232  NaN  NaN   NaN  NaN   NaN
# 1           NaN   NaN  NaN  655200420197  NaN  NaN   NaN  NaN   NaN
# 2           NaN   NaN  NaN  655200450172  NaN  NaN   NaN  NaN   NaN
# 3           NaN   NaN  NaN  655200450172  NaN  NaN   NaN  NaN   NaN
# 4           NaN   NaN  NaN  655200420197  NaN  NaN   NaN  NaN   NaN
# ...         ...   ...  ...           ...  ...  ...   ...  ...   ...
# 235533      NaN  GRAL  NaN  655210140012  NaN  NaN   ASP  DIP  PESD
# 235534      NaN   NaN  NaN  655210140033  NaN  NaN  GMTR  659  PESD
# 235535      NaN   K74  NaN  655210140033  NaN  NaN  NCON  654  PESD
# 235536      NaN   H54  NaN  655210140033  NaN  NaN   ASP  483  PESD
# 235537      NaN   NaN  NaN  655210140033  NaN  NaN  DGRC  659  PESD
#
# [235538 rows x 16 columns]

# %% [markdown]
# # Fill DPTO, TALL, UET
# Debido a la estructura jerarquica que se nos presenta, iremos completando los datos desde la UET hacía el DPTO debido a que algunos datos no son correctos.

# %%
hie = pd.read_excel(HIERARCHY, 'Datos')
hie.drop(columns=['DPTO', 'TALL', 'UET'], inplace=True)
hie.rename(columns={'DPTOACRO':'DPTO','TALLACRO':'TALL','UETACRO':'UET'}, inplace=True)

# %%
hie['DPTO'] = hie['DPTO'].astype(str)
hie['TALL'] = hie['TALL'].astype(str)
hie['UET'] = hie['UET'].astype(str)

# %%
hie['DPTO'].replace({'DCHAP':'SOLD', 'DPINT':'PINT', 'EMB ':'EMBU', 'DMONT':'MONT', 'MONTVU ':'MONT', 'CALID':'CALI'}, inplace=True)

# %%
# Completar taller en función a la UET
def fill_taller(uet):
    hieuet = hie.copy()
    hieuet.set_index('UET', inplace=True)
    try:
        return hieuet.loc[uet].TALL
    except:
        pass
    
df['TALL'] = df.apply(lambda row: fill_taller(row['UET']), axis=1)

# %%
df
# Out:
#         AUDI                        DECL  DPTO   ELE GVD   INC INOFFDPTO  \
# 0       CAPS  2020-01-27 09:00:00.000000  SOLD  4120  V2   180       NaN
# 1       CAPS  2020-01-27 09:00:00.000000  PINT  4466  V2  1010       NaN
# 2       CAPS  2020-01-27 09:00:00.000000  PINT  4420  V2  1110       NaN
# 3       CAPS  2020-01-27 09:00:00.000000  PINT  4412  V2  1180       NaN
# 4       CAPS  2020-01-27 09:00:00.000000  PINT  4414  V2  1270       NaN
# ...      ...                         ...   ...   ...  ..   ...       ...
# 235533  PESD         2020-12-30 09:06:00  PINT  4502  V2  1000       NaN
# 235534  PESD         2020-12-30 10:03:00  SOLD  7887  V2  3220       NaN
# 235535  PESD         2020-12-30 10:03:00  MONT  5215  V2  4450       NaN
# 235536  PESD         2020-12-30 10:03:00  PINT  4401  V2  1190       NaN
# 235537  PESD         2020-12-30 10:03:00  SOLD  4506  V2  1510       NaN
#
#        INOFFUSI   LOC MADU           PJI RETO   TALL  TIPO  UET  ZONA
# 0           NaN   NaN  NaN  655200530232  NaN   None   NaN  NaN   NaN
# 1           NaN   NaN  NaN  655200420197  NaN   None   NaN  NaN   NaN
# 2           NaN   NaN  NaN  655200450172  NaN   None   NaN  NaN   NaN
# 3           NaN   NaN  NaN  655200450172  NaN   None   NaN  NaN   NaN
# 4           NaN   NaN  NaN  655200420197  NaN   None   NaN  NaN   NaN
# ...         ...   ...  ...           ...  ...    ...   ...  ...   ...
# 235533      NaN  GRAL  NaN  655210140012  NaN  SERVP   ASP  DIP  PESD
# 235534      NaN   NaN  NaN  655210140033  NaN  TOLE4  GMTR  659  PESD
# 235535      NaN   K74  NaN  655210140033  NaN  CH-ME  NCON  654  PESD
# 235536      NaN   H54  NaN  655210140033  NaN  PTAL2   ASP  483  PESD
# 235537      NaN   NaN  NaN  655210140033  NaN  TOLE4  DGRC  659  PESD
#
# [235538 rows x 16 columns]

# %%
# Completar DPTO en función al taller
def fill_dpto(tall):
    hietall = hie.copy()
    hietall = hietall.drop(columns='UET').drop_duplicates(subset='TALL')
    hietall.set_index('TALL', inplace=True)
    try:
        return hietall.loc[tall].DPTO
    except:
        pass

df['DPTO'] = df.apply(lambda row: fill_dpto(row['TALL']), axis=1)

# %%
df
# Out:
#         AUDI                        DECL    DPTO   ELE GVD   INC INOFFDPTO  \
# 0       CAPS  2020-01-27 09:00:00.000000    None  4120  V2   180       NaN
# 1       CAPS  2020-01-27 09:00:00.000000    None  4466  V2  1010       NaN
# 2       CAPS  2020-01-27 09:00:00.000000    None  4420  V2  1110       NaN
# 3       CAPS  2020-01-27 09:00:00.000000    None  4412  V2  1180       NaN
# 4       CAPS  2020-01-27 09:00:00.000000    None  4414  V2  1270       NaN
# ...      ...                         ...     ...   ...  ..   ...       ...
# 235533  PESD         2020-12-30 09:06:00    PINT  4502  V2  1000       NaN
# 235534  PESD         2020-12-30 10:03:00    SOLD  7887  V2  3220       NaN
# 235535  PESD         2020-12-30 10:03:00  MONTVU  5215  V2  4450       NaN
# 235536  PESD         2020-12-30 10:03:00    PINT  4401  V2  1190       NaN
# 235537  PESD         2020-12-30 10:03:00    SOLD  4506  V2  1510       NaN
#
#        INOFFUSI   LOC MADU           PJI RETO   TALL  TIPO  UET  ZONA
# 0           NaN   NaN  NaN  655200530232  NaN   None   NaN  NaN   NaN
# 1           NaN   NaN  NaN  655200420197  NaN   None   NaN  NaN   NaN
# 2           NaN   NaN  NaN  655200450172  NaN   None   NaN  NaN   NaN
# 3           NaN   NaN  NaN  655200450172  NaN   None   NaN  NaN   NaN
# 4           NaN   NaN  NaN  655200420197  NaN   None   NaN  NaN   NaN
# ...         ...   ...  ...           ...  ...    ...   ...  ...   ...
# 235533      NaN  GRAL  NaN  655210140012  NaN  SERVP   ASP  DIP  PESD
# 235534      NaN   NaN  NaN  655210140033  NaN  TOLE4  GMTR  659  PESD
# 235535      NaN   K74  NaN  655210140033  NaN  CH-ME  NCON  654  PESD
# 235536      NaN   H54  NaN  655210140033  NaN  PTAL2   ASP  483  PESD
# 235537      NaN   NaN  NaN  655210140033  NaN  TOLE4  DGRC  659  PESD
#
# [235538 rows x 16 columns]

# %%
# Set type for cols
#df['PJI'] = df['PJI'].astype(int).astype(str)
df['ELE'] = df['ELE'].astype(str).str.zfill(4)
df['INC'] = df['INC'].astype(str).str.zfill(4)
df['LOC'] = df['LOC'].astype(str)

# %%
df.DPTO.replace({'MONTVU':'MONT'}, inplace=True)

# %%
df.GVD.unique()
# Out:
# array(['V2', 'V1', 'V1E', '0', 'v2'], dtype=object)

# %%
# Data homogenization
df['GVD'].replace({'P2':'V2', 
                   '0':'V2',
                   'v2':'V2',
                   'V2F':'V2',
                   'V1E':'V1',
                   '0':'V2',
                   'v2':'V2',
                   'V1+':'V1',
                   'V1C':'V1',
                   'V3':'V2',
                   'P1':'V1',
                   'V1E':'V1',
                   'V1F':'V1',
                   'V1C':'V1',
                   'V1B':'V1',
                   'V1D':'V1',
                   'V1A':'V1',
                   'V2B':'V2'}, inplace=True)

# %%
df = df[df['DECL']>='2020-01-01']

# %%
df = df[df['DECL']<'2021-01-01']

# %%
max(df.DECL)
# Out:
# '2020-12-30 14:35:16.999996'

# %%
df.to_csv(DATAOUTPUT)
